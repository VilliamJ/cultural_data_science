# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (2024.5.10)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (4.66.4)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import ssl
import nltk

ssl._create_default_https_context = ssl._create_unverified_context
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg

from nltk.corpus import gutenberg
import nltk
#nltk.download('gutenberg')

nltk.download('gutenberg', download_dir='/Users/villiamjensen/Downloads')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/villiamjensen/Downloads...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('bible-kjv.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['for the children of this world are in their generation',
#  'them, the children of this world marry, and are given',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'for the prince of this world cometh, and hath nothing',
#  'because the prince of this world is judged.  16:12',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'for the fashion of this world passeth away.  7:32',
#  'whom the god of this world hath blinded the minds',
#  'chosen the poor of this world rich in faith, and',
#  'saying, the kingdoms of this world are become the kingdoms']

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 13

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['and he hath set the world upon them.  2:9',
#  'appeared, the foundations of the world were discovered, at the',
#  'him, all the earth: the world also shall be stable,',
#  'upon the face of the world in the earth. ',
#  'and he shall judge the world in righteousness, he shall',
#  'and the foundations of the world were discovered at thy',
#  'all the ends of the world shall remember and turn',
#  'all the inhabitants of the world stand in awe of',
#  'not tell thee: for the world is mine, and the',
#  'is thine: as for the world and the fulness thereof,',
#  'he hath girded himself: the world also is stablished, that',
#  'that the lord reigneth: the world also shall be established',
#  'earth: he shall judge the world with righteousness, and the',
#  'also he hath set the world in their heart, so',
#  'and i will punish the world for their evil, and',
#  'kingdoms; 14:17 that made the world as a wilderness, and',
#  'fill the face of the world with cities.  14:22',
#  'all the kingdoms of the world upon the face of',
#  'mourneth and fadeth away, the world languisheth and fadeth away,',
#  'earth, the inhabitants of the world will learn righteousness. ',
#  'have the inhabitants of the world fallen.  26:19 thy',
#  'fill the face of the world with fruit.  27:7',
#  'not be ashamed nor confounded world without end.  45:18',
#  'since the beginning of the world men have not heard,',
#  'power, he hath established the world by his wisdom, and',
#  'power, he hath established the world by his wisdom, and',
#  'this world, neither in the world to come.  12:33',
#  ' 18:7 woe unto the world because of offences! for',
#  'be preached in all the world for a witness unto',
#  'since the beginning of the world to this time, no,',
#  'with persecutions; and in the world to come eternal life.',
#  'which have been since the world began: 1:71 that we',
#  'caesar augustus that all the world should be taxed. ',
#  'all the kingdoms of the world in a moment of',
#  'do the nations of the world seek after: and your',
#  'for the children of this world are in their generation',
#  'present time, and in the world to come life everlasting.',
#  'them, the children of this world marry, and are given',
#  'in the world, and the world was made by him,',
#  'made by him, and the world knew him not. ',
#  'not his son into the world to condemn the world;',
#  'the world; but that the world through him might be',
#  'alway ready.  7:7 the world cannot hate you; but',
#  'and i speak to the world those things which i',
#  'heareth.  9:32 since the world began was it not',
#  'ye prevail nothing? behold, the world is gone after him.',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'spirit of truth; whom the world cannot receive, because it',
#  'a little while, and the world seeth me no more;',
#  'unto you: not as the world giveth, give i unto',
#  'for the prince of this world cometh, and hath nothing',
#  ' 14:31 but that the world may know that i',
#  'another.  15:18 if the world hate you, ye know',
#  'were of the world, the world would love his own:',
#  'of the world, therefore the world hateth you.  15:20',
#  'come, he will reprove the world of sin, and of',
#  'because the prince of this world is judged.  16:12',
#  'weep and lament, but the world shall rejoice: and ye',
#  'have peace.  in the world ye shall have tribulation:',
#  'had with thee before the world was.  17:6 i',
#  'them thy word; and the world hath hated them, because',
#  'one in us: that the world may believe that thou',
#  'in one; and that the world may know that thou',
#  '17:25 o righteous father, the world hath not known thee:',
#  'i suppose that even the world itself could not contain',
#  'his holy prophets since the world began.  3:22 for',
#  'these that have turned the world upside down are come',
#  '17:24 god that made the world and all things therein,',
#  'which he will judge the world in righteousness by that',
#  'whom all asia and the world worshippeth.  19:28 and',
#  'from the creation of the world are clearly seen, being',
#  'be stopped, and all the world may become guilty before',
#  'was kept secret since the world began, 16:26 but now',
#  'the wisdom of god the world by wisdom knew not',
#  'the foolish things of the world to confound the wise;',
#  'the weak things of the world to confound the things',
#  'which god ordained before the world unto our glory: 2:8',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'the world? and if the world shall be judged by',
#  'for the fashion of this world passeth away.  7:32',
#  'eat no flesh while the world standeth, lest i make',
#  'whom the ends of the world are come.  10:12',
#  'whom the god of this world hath blinded the minds',
#  'was in christ, reconciling the world unto himself, not imputing',
#  'but the sorrow of the world worketh death.  7:11',
#  'jesus christ, by whom the world is crucified unto me,',
#  'from the beginning of the world hath been hid in',
#  'christ jesus throughout all ages, world without end. amen. ',
#  'christ jesus came into the world to save sinners; of',
#  'in christ jesus before the world began, 1:10 but is',
#  'cannot lie, promised before the world began; 1:3 but hath',
#  'not put in subjection the world to come, whereof we',
#  'and the powers of the world to come, 6:6 if',
#  'in the end of the world hath he appeared to',
#  'tormented; 11:38 (of whom the world was not worthy:) they',
#  'chosen the poor of this world rich in faith, and',
#  'tongue is a fire, a world of iniquity: so is',
#  'that the friendship of the world is enmity with god?',
#  'be a friend of the world is the enemy of',
#  'corruption that is in the world through lust.  1:5',
#  'in the flood upon the world of the ungodly; 2:6',
#  'escaped the pollutions of the world through the knowledge of',
#  'the water: 3:6 whereby the world that then was, being',
#  'world.  2:17 and the world passeth away, and the',
#  'sons of god: therefore the world knoweth us not, because',
#  'not, my brethren, if the world hate you.  3:14',
#  'of the world, and the world heareth them.  4:6',
#  'of god, and the whole world lieth in wickedness. ',
#  'saying, the kingdoms of this world are become the kingdoms',
#  'was healed: and all the world wondered after the beast.']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 113

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
concordance2 = []
for i, val in enumerate(bible):
    if val.lower() == "god":  # Use .lower() for case-insensitive matching
        # Check that we're not accessing out-of-bound indices
        if i >= 3 and i + 3 < len(bible):
            concordance2.append(' '.join(bible[i-3:i+3]))

# %%
concordance2
# Out:
# ['in the beginning god created the',
#  'the spirit of god moved upon',
#  ' 1:3 and god said, let',
#  ' 1:4 and god saw the',
#  'was good: and god divided the',
#  ' 1:5 and god called the',
#  ' 1:6 and god said, let',
#  ' 1:7 and god made the',
#  ' 1:8 and god called the',
#  ' 1:9 and god said, let',
#  ' 1:10 and god called the',
#  'he seas: and god saw that',
#  ' 1:11 and god said, let',
#  'his kind: and god saw that',
#  ' 1:14 and god said, let',
#  ' 1:16 and god made two',
#  ' 1:17 and god set them',
#  'the darkness: and god saw that',
#  ' 1:20 and god said, let',
#  ' 1:21 and god created great',
#  'his kind: and god saw that',
#  ' 1:22 and god blessed them,',
#  ' 1:24 and god said, let',
#  ' 1:25 and god made the',
#  'his kind: and god saw that',
#  ' 1:26 and god said, let',
#  ' 1:27 so god created man',
#  'the image of god created he',
#  ' 1:28 and god blessed them,',
#  'blessed them, and god said unto',
#  ' 1:29 and god said, behold,',
#  ' 1:31 and god saw every',
#  'the seventh day god ended his',
#  ' 2:3 and god blessed the',
#  'his work which god created and',
#  'that the lord god made the',
#  'for the lord god had not',
#  'and the lord god formed man',
#  'and the lord god planted a',
#  'made the lord god to grow',
#  'and the lord god took the',
#  'and the lord god commanded the',
#  'and the lord god said, it',
#  'ground the lord god formed every',
#  'and the lord god caused a',
#  'which the lord god had taken',
#  'which the lord god had made.',
#  'woman, yea, hath god said, ye',
#  'of the garden, god hath said,',
#  'die: 3:5 for god doth know',
#  'of the lord god walking in',
#  'of the lord god amongst the',
#  'and the lord god called unto',
#  'and the lord god said unto',
#  'and the lord god said unto',
#  'did the lord god make coats',
#  'and the lord god said, behold,',
#  'therefore the lord god sent him',
#  'the day that god created man,',
#  'the likeness of god made he',
#  'enoch walked with god after he',
#  'was not; for god took him.',
#  'the sons of god saw the',
#  'the sons of god came in',
#  ' 6:5 and god saw that',
#  ' 6:12 and god looked upon',
#  ' 6:13 and god said unto',
#  'to all that god commanded him,',
#  'the female, as god had commanded',
#  'all flesh, as god had commanded',
#  ' 8:1 and god remembered noah,',
#  'the ark: and god made a',
#  ' 8:15 and god spake unto',
#  ' 9:1 and god blessed noah',
#  'the image of god made he',
#  ' 9:8 and god spake unto',
#  ' 9:12 and god said, this',
#  'everlasting covenant between god and every',
#  ' 9:17 and god said unto',
#  'be the lord god of shem;',
#  'servant.  9:27 god shall enlarge',
#  'unto her, thou god seest me:',
#  'his face: and god talked with',
#  'to be a god unto thee,',
#  ' 17:9 and god said unto',
#  ' 17:15 and god said unto',
#  ' 17:19 and god said, sarah',
#  'with him, and god went up',
#  'selfsame day, as god had said',
#  'to pass, when god destroyed the',
#  'the plain, that god remembered abraham,',
#  ' 20:3 but god came to',
#  ' 20:6 and god said unto',
#  'the fear of god is not',
#  'to pass, when god caused me',
#  'unto god: and god healed abimelech,',
#  'time of which god had spoken',
#  'days old, as god had commanded',
#  'and sarah said, god hath made',
#  ' 21:12 and god said unto',
#  ' 21:17 and god heard the',
#  'the angel of god called to',
#  'fear not; for god hath heard',
#  ' 21:19 and god opened her',
#  ' 21:20 and god was with',
#  'unto abraham, saying, god is with',
#  'me here by god that thou',
#  'these things, that god did tempt',
#  'place of which god had told',
#  'said, my son, god will provide',
#  'the place which god had told',
#  'the lord, the god of heaven,',
#  'heaven, and the god of the',
#  '24:7 the lord god of heaven,',
#  'said o lord god of my',
#  'be the lord god of my',
#  'said, o lord god of my',
#  'blessed the lord god of my',
#  'of abraham, that god blessed his',
#  'i am the god of abraham',
#  'the lord thy god brought it',
#  'blessed: 27:28 therefore god give thee',
#  ' 28:3 and god almighty bless',
#  'a stranger, which god gave unto',
#  'the angels of god ascending and',
#  'am the lord god of abraham',
#  'father, and the god of isaac:',
#  'vow, saying, if god will be',
#  'and rachel said, god hath judged',
#  ' 30:17 and god hearkened unto',
#  'and leah said, god hath given',
#  'and leah said, god hath endued',
#  ' 30:22 and god remembered rachel,',
#  'remembered rachel, and god hearkened to',
#  'son; and said, god hath taken',
#  'before; but the god of my',
#  'ten times; but god suffered him',
#  ' 31:9 thus god hath taken',
#  'the angel of god spake unto',
#  'i am the god of bethel,',
#  'the riches which god hath taken',
#  'now then, whatsoever god hath said',
#  ' 31:24 and god came to',
#  'hurt: but the god of your',
#  '31:42 except the god of my',
#  'my father, the god of abraham,',
#  'away now empty. god hath seen',
#  'with us; see, god is witness',
#  ' 31:53 the god of abraham,',
#  'abraham, and the god of nahor,',
#  'of nahor, the god of their',
#  'the angels of god met him.',
#  'jacob said, o god of my',
#  'father abraham, and god of my',
#  'thou power with god and with',
#  'i have seen god face to',
#  'the children which god hath graciously',
#  'to thee; because god hath dealt',
#  'harlot? 35:1 and god said unto',
#  'the terror of god was upon',
#  'elbethel: because there god appeared unto',
#  ' 35:9 and god appeared unto',
#  ' 35:10 and god said unto',
#  ' 35:11 and god said unto',
#  'him, i am god almighty: be',
#  ' 35:13 and god went up',
#  'the place where god spake with',
#  'not in me: god shall give',
#  'pharaoh is one: god hath shewed',
#  'unto pharaoh: what god is about',
#  'by god, and god will shortly',
#  'the spirit of god is? ',
#  'joseph, forasmuch as god hath shewed',
#  'he ephraim: for god hath caused',
#  'is this that god hath done',
#  'man: 43:14 and god almighty give',
#  'god, and the god of your',
#  'and he said, god be gracious',
#  'lord these words? god forbid that',
#  'we clear ourselves? god hath found',
#  'and he said, god forbid that',
#  'me hither: for god did send',
#  ' 45:7 and god sent me',
#  'thy son joseph, god hath made',
#  'sacrifices unto the god of his',
#  ' 46:2 and god spake unto',
#  'am god, the god of thy',
#  'said unto joseph, god almighty appeared',
#  'my sons, whom god hath given',
#  'face: and, lo, god hath shewed',
#  'did walk, the god which fed',
#  'israel bless, saying, god make thee',
#  'i die: but god shall be',
#  'of the mighty god of jacob;',
#  'even by the god of thy',
#  'servants of the god of thy',
#  'against me; but god meant it',
#  'i die: and god will surely',
#  'of israel, saying, god will surely',
#  ' 1:20 therefore god dealt well',
#  'came up unto god by reason',
#  ' 2:24 and god heard their',
#  'their groaning, and god remembered his',
#  ' 2:25 and god looked upon',
#  'of israel, and god had respect',
#  'aside to see, god called unto',
#  'i am the god of thy',
#  'thy father, the god of abraham,',
#  'of abraham, the god of isaac,',
#  'isaac, and the god of jacob.',
#  'ye shall serve god upon this',
#  'unto them, the god of your',
#  ' 3:14 and god said unto',
#  ' 3:15 and god said moreover',
#  'israel, the lord god of your',
#  'your fathers, the god of abraham,',
#  'of abraham, the god of isaac,',
#  'isaac, and the god of jacob,',
#  'them, the lord god of your',
#  'your fathers, the god of abraham,',
#  'him, the lord god of the',
#  'that the lord god of their',
#  'their fathers, the god of abraham,',
#  'of abraham, the god of isaac,',
#  'isaac, and the god of jacob,',
#  'the rod of god in his',
#  'saith the lord god of israel,',
#  'they said, the god of the',
#  ' 6:2 and god spake unto',
#  'the name of god almighty, but',
#  'made thee a god to pharaoh:',
#  'him, the lord god of the',
#  'sacrifice to your god in the',
#  'the lord your god in the',
#  'saith the lord god of the',
#  'saith the lord god of the',
#  'saith the lord god of the',
#  'people go, that god led them',
#  'was near; for god said, lest',
#  'egypt: 13:18 but god led the',
#  'of israel, saying, god will surely',
#  'them, would to god we had',
#  'the rod of god in mine',
#  'of all that god had done',
#  'eliezer; for the god of my',
#  'thee counsel, and god shall be',
#  'this thing, and god command thee',
#  'moses spake, and god answered him',
#  ' 20:1 and god spake all',
#  'the lord thy god am a',
#  'the lord thy god in vain;',
#  'the lord thy god giveth thee.',
#  'but let not god speak with',
#  'fear not: for god is come',
#  'thick darkness where god was. ',
#  'in wait, but god deliver him',
#  'they saw the god of israel:',
#  'saith the lord god of israel,',
#  'lord god, the god of israel.',
#  'the lord thy god thrice in',
#  'covenant of thy god to be',
#  'the lord his god concerning things',
#  'most holy, and god hath given',
#  'the lord your god am holy.',
#  'oil of his god is upon',
#  'bread of your god of any',
#  'the lord your god seven days.',
#  'whosoever curseth his god shall bear',
#  'consecration of his god is upon',
#  'my sake? would god that all',
#  'unto them, would god that we',
#  'egypt! or would god we had',
#  'you, that the god of israel',
#  'o god, the god of the',
#  'spake, saying, would god that we',
#  ' 22:9 and god came unto',
#  ' 22:12 and god said unto',
#  ' 22:20 and god came unto',
#  'the word that god putteth in',
#  ' 23:4 and god met balaam:',
#  'i curse, whom god hath not',
#  'of zippor: 23:19 god is not',
#  'the lord his god is with',
#  'them.  23:22 god brought them',
#  'israel, what hath god wrought! ',
#  'it will please god that thou',
#  'the spirit of god came upon',
#  'exalted.  24:8 god brought him',
#  'shall live when god doeth this!',
#  'the lord, the god of the',
#  'the lord our god spake unto',
#  'the lord your god hath multiplied',
#  '1:11 (the lord god of your',
#  'the lord our god commanded us;',
#  'the lord our god doth give',
#  'the lord thy god hath set',
#  'as the lord god of thy',
#  'the lord our god doth give',
#  'the lord your god which goeth',
#  'the lord thy god bare thee,',
#  'the lord our god commanded us.',
#  'the lord thy god hath blessed',
#  'the lord thy god hath been',
#  'the lord our god giveth us.',
#  'the lord thy god hardened his',
#  'the lord our god delivered him',
#  'the lord our god delivered all',
#  'the lord our god forbad us.',
#  'the lord our god delivered into',
#  'the lord your god hath given',
#  'the lord your god hath given',
#  'the lord your god hath done',
#  'the lord your god he shall',
#  'hand: for what god is there',
#  'which the lord god of your',
#  'the lord your god which i',
#  'the lord thy god hath destroyed',
#  'the lord your god are alive',
#  'the lord my god commanded me,',
#  'great, who hath god so nigh',
#  'the lord our god is in',
#  'the lord thy god in horeb,',
#  'the lord thy god hath divided',
#  'the lord thy god giveth thee',
#  'the lord thy god hath forbidden',
#  'the lord thy god is a',
#  'the lord thy god is a',
#  'the day that god created man',
#  'the voice of god speaking out',
#  '4:34 or hath god assayed to',
#  'the lord your god did for',
#  'lord he is god in heaven',
#  'the lord thy god giveth thee,',
#  'the lord our god made a',
#  'the lord thy god am a',
#  'the lord thy god in vain:',
#  'the lord thy god hath commanded',
#  'the lord thy god brought thee',
#  'the lord thy god commanded thee',
#  'the lord thy god hath commanded',
#  'the lord thy god giveth thee.',
#  'the lord our god hath shewed',
#  'this day that god doth talk',
#  'the lord our god any more,',
#  'of the living god speaking out',
#  'the lord our god shall say:',
#  'the lord our god shall speak',
#  'the lord your god hath commanded',
#  'the lord your god hath commanded',
#  'the lord your god commanded to',
#  'as the lord god of thy',
#  'the lord our god is one',
#  'the lord thy god with all',
#  'the lord thy god shall have',
#  'the lord thy god is a',
#  'is a jealous god among you)',
#  'the lord thy god be kindled',
#  'the lord our god hath commanded',
#  'the lord thy god shall bring',
#  'the lord thy god shall deliver',
#  'the lord thy god hath chosen',
#  'the lord thy god shall keep',
#  'the lord thy god shall deliver',
#  'the lord thy god did unto',
#  'the lord thy god brought thee',
#  'the lord thy god do unto',
#  'the lord thy god will send',
#  'the lord thy god is among',
#  'you, a mighty god and terrible.',
#  'the lord thy god will put',
#  'the lord thy god shall deliver',
#  'the lord thy god led thee',
#  'the lord thy god chasteneth thee.',
#  'the lord thy god bringeth thee',
#  'the lord thy god for the',
#  'the lord thy god is he',
#  'the lord thy god hath cast',
#  'the lord thy god doth drive',
#  'the lord thy god giveth thee',
#  'the lord thy god to wrath',
#  'the lord thy god promised him.',
#  'the lord thy god require of',
#  'the lord thy god with all',
#  'the lord your god is god',
#  'your god is god of gods,',
#  'the lord thy god hath made',
#  'the lord thy god careth for:',
#  'the lord thy god are always',
#  'the lord your god shall lay',
#  'the lord thy god hath brought',
#  'the lord your god giveth you,',
#  'which the lord god of thy',
#  'the lord your god shall choose',
#  'the lord thy god hath blessed',
#  'the lord your god giveth you.',
#  'the lord your god giveth you',
#  'the lord your god shall choose',
#  'the lord thy god which he',
#  'the lord thy god in the',
#  'the lord thy god shall choose,',
#  'the lord thy god in all',
#  'the lord thy god shall enlarge',
#  'the lord thy god hath chosen',
#  'the lord thy god shall cut',
#  'the lord your god proveth you,',
#  'the lord your god with all',
#  'the lord thy god commanded thee',
#  'the lord thy god hath given',
#  'the lord thy god always. ',
#  'the lord thy god shall choose',
#  'the lord thy god hath blessed',
#  'the lord thy god shall choose:',
#  'the lord thy god may bless',
#  'the lord thy god giveth thee',
#  'the lord thy god blesseth thee,',
#  'the lord thy god giveth thee,',
#  'the lord thy god shall bless',
#  'the lord thy god hath blessed',
#  'the lord thy god redeemed thee:',
#  'the lord thy god shall bless',
#  'the lord thy god year by',
#  'the lord thy god brought thee',
#  'the lord thy god giveth thee:',
#  'the lord thy god shall choose',
#  'the lord thy god shall choose:',
#  'the lord thy god with a',
#  'the lord thy god hath blessed',
#  'the lord thy god hath chosen',
#  'the lord thy god in the',
#  'the lord thy god shall bless',
#  'the lord thy god in the',
#  'the lord thy god which he',
#  'the lord thy god giveth thee,',
#  'the lord thy god giveth thee.',
#  'the lord thy god hateth. ',
#  'the lord thy god any bullock,',
#  'the lord thy god giveth thee,',
#  'the lord thy god shall choose;',
#  'the lord thy god giveth thee,',
#  'the lord thy god shall choose:',
#  'the lord thy god hath chosen',
#  'the lord thy god giveth thee,',
#  'the lord thy god doth drive',
#  'the lord thy god hath not',
#  'the lord thy god will raise',
#  'the lord thy god in horeb',
#  'the lord thy god hath cut',
#  'the lord thy god giveth thee,',
#  'the lord thy god giveth thee',
#  'the lord thy god giveth thee',
#  'the lord thy god enlarge thy',
#  'the lord thy god giveth thee',
#  'the lord thy god giveth thee',
#  'the lord thy god is with',
#  'the lord your god is he',
#  'the lord thy god hath delivered',
#  'the lord thy god hath given',
#  'the lord thy god doth give',
#  'the lord thy god hath commanded',
#  'the lord thy god giveth thee',
#  'the lord thy god hath chosen',
#  'the lord thy god hath delivered',
#  'the lord thy god giveth thee',
#  'the lord thy god would not',
#  'the lord thy god turned the',
#  'the lord thy god loved thee.',
#  'the lord thy god walketh in',
#  'the lord thy god for any',
#  'the lord thy god may bless',
#  'the lord thy god will surely',
#  'the lord thy god giveth thee',
#  'the lord thy god did unto',
#  'the lord thy god redeemed thee',
#  'the lord thy god may bless',
#  'the lord thy god giveth thee.',
#  'the lord thy god hath given',
#  'the lord thy god giveth thee',
#  'the lord thy god giveth thee',
#  'the lord thy god giveth thee,',
#  'the lord thy god shall choose',
#  'unto the lord god of our',
#  'the lord thy god hath given',
#  'the lord thy god hath commanded',
#  'the lord thy god giveth thee,',
#  'the lord thy god giveth thee,',
#  'as the lord god of thy',
#  'the lord thy god of whole',
#  'the lord thy god will set',
#  'the lord thy god giveth thee.',
#  'the lord thy god with joyfulness,',
#  'the lord thy god hath given',
#  'the lord thy god hath given',
#  'shalt say, would god it were',
#  'shalt say, would god it were',
#  'the lord thy god maketh with',
#  'of the lord god of their',
#  'the lord thy god hath driven',
#  'the lord thy god will turn',
#  'the lord thy god hath scattered',
#  'the lord thy god gather thee,',
#  'the lord thy god will bring',
#  'the lord thy god will circumcise',
#  'the lord thy god with all',
#  'the lord thy god will put',
#  'the lord thy god will make',
#  'the lord thy god with all',
#  'the lord thy god shall bless',
#  'the lord thy god in the',
#  'us, because our god is not',
#  'are judgment: a god of truth',
#  'was no strange god with him.',
#  'then he forsook god which made',
#  'and hast forgotten god that formed',
#  'there is no god with me:',
#  'the man of god blessed the',
#  'like unto the god of jeshurun,',
#  '33:27 the eternal god is thy',
#  'the lord thy god is with',
#  'the lord your god giveth you',
#  'the lord your god hath given',
#  'the lord your god giveth them:',
#  'the lord thy god be with',
#  'god, he is god in heaven',
#  'that the living god is among',
#  'the lord your god into the',
#  'the lord your god dried up',
#  'the lord your god did to',
#  'the lord your god for ever.',
#  'us? would to god we had',
#  'saith the lord god of israel,',
#  'to the lord god of israel,',
#  'against the lord god of israel,',
#  'the lord your god will deliver',
#  'unto the lord god of israel',
#  'by the lord god of israel.',
#  'by the lord god of israel:',
#  'the lord thy god commanded his',
#  'the lord your god hath delivered',
#  'as the lord god of israel',
#  'because the lord god of israel',
#  'of the lord god of israel',
#  'inheritance: the lord god of israel',
#  'the man of god concerning me',
#  'followed the lord god of israel.',
#  'which the lord god of your',
#  'the lord your god hath given',
#  'committed against the god of israel,',
#  '22:22 the lord god of gods,',
#  'gods, the lord god of gods,',
#  'with the lord god of israel?',
#  'you.  22:29 god forbid that',
#  'the lord our god that is',
#  'the lord your god hath done',
#  'the lord your god is he',
#  'the lord your god hath promised',
#  'the lord your god will no',
#  'the lord your god hath given',
#  'the lord your god spake concerning',
#  'the lord your god promised you;',
#  'the lord your god hath given',
#  'saith the lord god of israel,',
#  'answered and said, god forbid that',
#  'unto the lord god of israel.',
#  'the lord our god will we',
#  'have done, so god hath requited',
#  'forsook the lord god of their',
#  'a message from god unto thee.',
#  'not the lord god of israel',
#  ' 4:23 so god subdued on',
#  'to the lord god of israel.',
#  'before the lord god of israel.',
#  'saith the lord god of israel,',
#  'the angel of god said unto',
#  'the lord thy god upon the',
#  ' 6:40 and god did so',
#  'his hand hath god delivered midian,',
#  'abiezer?  8:3 god hath delivered',
#  'of shechem, that god may hearken',
#  'me they honour god and man,',
#  'wine, which cheereth god and man,',
#  'israel, 9:23 then god sent an',
#  'and would to god this people',
#  'house of the god berith. ',
#  ' 9:56 thus god rendered the',
#  'of shechem did god render upon',
#  'and the lord god of israel',
#  'now the lord god of israel',
#  'which chemosh thy god giveth thee',
#  'the lord our god shall drive',
#  'a nazarite unto god from the',
#  'a man of god came unto',
#  'a nazarite to god from the',
#  'the man of god which thou',
#  ' 13:9 and god hearkened to',
#  'the angel of god came again',
#  ' 15:19 but god clave an',
#  'a nazarite unto god from my',
#  'they said, our god hath delivered',
#  'they said, our god hath delivered',
#  'large land: for god hath given',
#  'the house of god was in',
#  'the covenant of god was there',
#  'said, o lord god of israel,',
#  'people, and thy god my god:',
#  'of the lord god of israel,',
#  'peace: and the god of israel',
#  'lord is a god of knowledge,',
#  'a man of god unto eli,',
#  'wherefore the lord god of israel',
#  'the wealth which god shall give',
#  'the lamp of god went out',
#  'the ark of god was, and',
#  'not from me: god do so',
#  'for they said, god is come',
#  'the ark of god was taken;',
#  'the ark of god is taken.',
#  'the ark of god was taken,',
#  'the ark of god was taken,',
#  'the ark of god is taken.',
#  'ark of the god of israel',
#  'ark of the god of israel?',
#  'ark of the god of israel',
#  'ark of the god of israel',
#  'the ark of god to ekron.',
#  'the ark of god came to',
#  'ark of the god of israel',
#  'ark of the god of israel,',
#  'the hand of god was very',
#  'ark of the god of israel,',
#  'glory unto the god of israel:',
#  'the lord our god for us,',
#  'the man of god was. ',
#  'going up to god to bethel,',
#  'serve thee; for god is with',
#  'go from samuel, god gave him',
#  'the spirit of god came upon',
#  'saith the lord god of israel,',
#  'shouted, and said, god save the',
#  'men, whose hearts god had touched.',
#  'the spirit of god came upon',
#  'the lord your god was your',
#  'as for me, god forbid that',
#  'the ark of god was at',
#  'unto the lord god of israel,',
#  'and saul answered, god do so',
#  'salvation in israel? god forbid: as',
#  'hath wrought with god this day.',
#  'the lord thy god in gilgal.',
#  'evil spirit from god troubleth thee.',
#  'evil spirit from god is upon',
#  'evil spirit from god was upon',
#  'of hosts, the god of the',
#  'there is a god in israel.',
#  'evil spirit from god came upon',
#  'the spirit of god was upon',
#  'the spirit of god was upon',
#  'said unto him, god forbid; thou',
#  'david, o lord god of israel,',
#  'i know what god will do',
#  'hast enquired of god for him,',
#  'to enquire of god for him?',
#  'and saul said, god hath delivered',
#  'david, o lord god of israel,',
#  'heard? o lord god of israel,',
#  'every day, but god delivered him',
#  'more also do god unto the',
#  'be the lord god of israel,',
#  'as the lord god of israel',
#  'abishai to david, god hath delivered',
#  'against me, and god is departed',
#  'joab said, as god liveth, unless',
#  '3:9 so do god to abner,',
#  'saying, so do god to me,',
#  'and the lord god of hosts',
#  'the ark of god upon a',
#  'against uzzah; and god smote him',
#  'the ark of god from the',
#  'the ark of god dwelleth within',
#  'is there any god beside thee,',
#  'like israel, whom god went to',
#  'hosts is the god over israel:',
#  'lord of hosts, god of israel,',
#  'the kindness of god unto him?',
#  'saith the lord god of israel,',
#  'david therefore besought god for the',
#  'can tell whether god will be',
#  'again; neither doth god respect any',
#  'the lord thy god will be',
#  'the ark of god into the',
#  'the ark of god again to',
#  'said unto absalom, god save the',
#  'save the king, god save the',
#  'son absalom! would god i had',
#  'of my flesh? god do so',
#  'and after that god was intreated',
#  'deliverer; 22:3 the god of my',
#  'troop: by my god have i',
#  'our god? 22:33 god is my',
#  'exalted be the god of the',
#  '22:48 it is god that avengeth',
#  'anointed of the god of jacob,',
#  ' 23:3 the god of israel',
#  'the lord thy god add unto',
#  'the lord thy god accept thee.',
#  'the lord my god of that',
#  'the lord thy god unto thine',
#  'him, and say, god save king',
#  'by the lord god of israel,',
#  'trumpet, and say, god save king',
#  'amen: the lord god of my',
#  'the people said, god save king',
#  'king david, saying, god make the',
#  'be the lord god of israel,',
#  'the lord, saying, god do so',
#  'of the lord god before david',
#  'by night: and god said, ask',
#  ' 3:11 and god said unto',
#  'the wisdom of god was in',
#  ' 4:29 and god gave solomon',
#  'the lord his god for the',
#  'the lord my god hath given',
#  'be the lord god of israel,',
#  'of the lord god of israel.',
#  'of the lord god of israel.',
#  'he said, lord god of israel,',
#  'there is no god like thee,',
#  'therefore now, lord god of israel,',
#  'and now, o god of israel,',
#  '8:27 but will god indeed dwell',
#  'the lord our god be with',
#  'the lord our god day and',
#  'his wisdom, which god had put',
#  'from the lord god of israel,',
#  ' 11:23 and god stirred him',
#  'the lord, the god of israel,',
#  'zidonians, chemosh the god of the',
#  'and milcom the god of the',
#  'the word of god came unto',
#  'a man of god out of',
#  'the man of god had given',
#  'the man of god besought the',
#  'the man of god said unto',
#  'the man of god had done',
#  'the man of god went, which',
#  'the man of god that camest',
#  'the man of god that came',
#  'the lord thy god commanded thee,',
#  'the man of god is buried;',
#  'saith the lord god of israel,',
#  'toward the lord god of israel',
#  'the lord his god give him',
#  'provoked the lord god of israel',
#  'provoking the lord god of israel',
#  'provoke the lord god of israel',
#  'provoke the lord god of israel',
#  'as the lord god of israel',
#  'the lord thy god liveth, i',
#  'saith the lord god of israel,',
#  'the lord thy god liveth, there',
#  'lord: and the god that answereth',
#  'and said, lord god of abraham,',
#  'that thou art god in israel,',
#  'for the lord god of hosts:',
#  'for the lord god of hosts:',
#  'the lord is god of the',
#  'he is not god of the',
#  'thou didst blaspheme god and the',
#  'naboth did blaspheme god and the',
#  'anger the lord god of israel,',
#  'of baalzebub the god of ekron',
#  'is not a god in israel,',
#  'of baalzebub the god of ekron?',
#  'is not a god in israel,',
#  'of baalzebub the god of ekron?',
#  'the fire of god came down',
#  'of baalzebub the god of ekron,',
#  'there is no god in israel',
#  'is the lord god of elijah?',
#  'the man of god to mount',
#  'the man of god saw her',
#  'the man of god to the',
#  'the man of god said, let',
#  'the man of god bread of',
#  'her mistress, would god my lord',
#  'the man of god had heard',
#  'there is no god in all',
#  'the man of god said, where',
#  'the man of god sent unto',
#  'the man of god told him',
#  'the man of god was risen',
#  'then he said, god do so',
#  'the man of god had said,',
#  'the man of god had spoken',
#  'the man of god is come',
#  'the man of god wept. ',
#  'saith the lord god of israel,',
#  'of the lord god of israel',
#  'hands, and said, god save the',
#  'the man of god was wroth',
#  'of the lord god of israel,',
#  'manner of the god of the',
#  'manner of the god of the',
#  'manner of the god of the',
#  'the lord your god ye shall',
#  'in the lord god of israel;',
#  'the lord thy god will hear',
#  'the lord thy god hath heard:',
#  'let not thy god in whom',
#  'said, o lord god of israel,',
#  'saith the lord god of israel,',
#  'the lord, the god of david',
#  'saith the lord god of israel,',
#  'forsook the lord god of his',
#  'saith the lord god of israel,',
#  'saith the lord god of israel,',
#  'the man of god proclaimed, who',
#  'called on the god of israel,',
#  'grieve me! and god granted him',
#  'they cried to god in the',
#  'transgressed against the god of their',
#  'the land, whom god destroyed before',
#  '5:26 and the god of israel',
#  'the servant of god had commanded.',
#  'the lord thy god said unto',
#  'and said, my god forbid it',
#  'mine hands, the god of our',
#  'helpers; for thy god helpeth thee.',
#  'ark of our god to us:',
#  'the ark of god from kirjathjearim.',
#  'the ark of god the lord,',
#  'the ark of god in a',
#  'israel played before god with all',
#  'was afraid of god that day,',
#  'the ark of god home to',
#  'the ark of god remained with',
#  'then david said, god hath broken',
#  'of god; and god said unto',
#  'to battle: for god is gone',
#  'therefore did as god commanded him:',
#  'the ark of god but the',
#  'of the lord god of israel',
#  'the lord our god made a',
#  'of the lord god of israel.',
#  'the ark of god upon their',
#  'to pass, when god helped the',
#  'praise the lord god of israel:',
#  'save us, o god of our',
#  'be the lord god of israel',
#  'thine heart; for god is with',
#  'the word of god came to',
#  'is there any god beside thee,',
#  'people israel, whom god went to',
#  'hosts is the god of israel,',
#  'israel, even a god to israel:',
#  ' 21:7 and god was displeased',
#  ' 21:15 and god sent an',
#  'for the lord god of israel.',
#  'the lord your god with you?',
#  'said, the lord god of israel',
#  'as the lord god of israel',
#  'the horn. and god gave to',
#  'the eighth: for god blessed him.',
#  'building: 28:3 but god said unto',
#  'howbeit the lord god of israel',
#  'know thou the god of thy',
#  'son, whom alone god hath chosen,',
#  'house of my god the gold',
#  'the house of god of gold',
#  'be thou, lord god of israel',
#  '29:18 o lord god of abraham,',
#  'blessed the lord god of their',
#  'the lord his god was with',
#  'the ark of god had david',
#  'that night did god appear unto',
#  ' 1:11 and god said to',
#  'great is our god above all',
#  'be the lord god of israel,',
#  'be the lord god of israel,',
#  'of the lord god of israel.',
#  'of the lord god of israel.',
#  'said, o lord god of israel,',
#  'there is no god like thee',
#  'therefore, o lord god of israel,',
#  'then, o lord god of israel,',
#  '6:18 but will god in very',
#  'forsook the lord god of their',
#  'the man of god commanded. ',
#  'god: because thy god loved israel,',
#  'his wisdom, that god had put',
#  'seek the lord god of israel',
#  'unto the lord god of their',
#  'that the lord god of israel',
#  '13:12 and, behold, god himself is',
#  'against the lord god of your',
#  'to pass, that god smote jeroboam',
#  'before judah: and god delivered them',
#  'upon the lord god of their',
#  'seek the lord god of their',
#  'the spirit of god came upon',
#  'unto the lord god of israel,',
#  'of city: for god did vex',
#  'the lord his god was with',
#  'seek the lord god of their',
#  'seek the lord god of israel',
#  'the house of god the things',
#  'to the lord god of his',
#  'go up; for god will deliver',
#  'even what my god saith, that',
#  'helped him; and god moved them',
#  'unto the lord god of their',
#  'said, o lord god of our',
#  'art not thou god in heaven?',
#  'praise the lord god of israel',
#  'the fear of god was on',
#  'quiet: for his god gave him',
#  'hearts unto the god of their',
#  'forsaken the lord god of his',
#  'saith the lord god of david',
#  'ahaziah was of god by coming',
#  'the house of god six years:',
#  'him, and said, god save the',
#  'house of your god from year',
#  'the servant of god laid upon',
#  'the house of god in his',
#  'of the lord god of their',
#  'the spirit of god came upon',
#  'forsaken the lord god of their',
#  'a man of god to him,',
#  'for the battle: god shall make',
#  'the enemy: for god hath power',
#  'the man of god answered, the',
#  'i know that god hath determined',
#  'the house of god with obededom,',
#  'and he sought god in the',
#  'sought the lord, god made him',
#  ' 26:7 and god helped him',
#  'the lord his god delivered him',
#  'forsaken the lord god of their',
#  'because the lord god of your',
#  'anger the lord god of his',
#  'of the lord god of your',
#  'place unto the god of israel.',
#  'with the lord god of israel,',
#  'the people, that god had prepared',
#  'unto the lord god of israel.',
#  'unto the lord god of israel',
#  'unto the lord god of abraham,',
#  'against the lord god of their',
#  'the lord your god is gracious',
#  'the hand of god was to',
#  'god, the lord god of his',
#  'to the lord god of their',
#  'the lord our god to help',
#  'the lord our god shall deliver',
#  'hand, that your god should be',
#  'him: for no god of any',
#  'less shall your god deliver you',
#  'on the lord god of israel,',
#  'shall not the god of hezekiah',
#  'spake against the god of jerusalem,',
#  'in abundance: for god had given',
#  'in the land, god left him,',
#  'god, of which god had said',
#  'greatly before the god of his',
#  'serve the lord god of israel.',
#  'the lord their god only. ',
#  'of the lord god of israel,',
#  'also, and how god was intreated',
#  'seek after the god of david',
#  'saith the lord god of israel,',
#  'saith the lord god of israel',
#  'of god, the god of their',
#  'the lord, the god of their',
#  'have war: for god commanded me',
#  'unto the lord god of israel.',
#  'and the lord god of their',
#  'hath the lord god of heaven',
#  'the lord his god be with',
#  'persia, the lord god of heaven',
#  'his people? his god be with',
#  'of the lord god of israel,',
#  'the house of god that is',
#  'them whose spirit god had raised,',
#  'the house of god to set',
#  'altar of the god of israel,',
#  'the house of god at jerusalem,',
#  'unto the lord god of israel;',
#  'unto the lord god of israel,',
#  'the house of god which is',
#  'name of the god of israel,',
#  'the house of god which is',
#  'the prophets of god helping them.',
#  'eye of their god was upon',
#  'servants of the god of heaven',
#  'had provoked the god of heaven',
#  'the house of god be builded',
#  'the house of god which is',
#  'this house of god at jerusalem,',
#  'the house of god at jerusalem,',
#  'this house of god alone; let',
#  ...]

# %%
len(concordance2)
# Out:
# 2303

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here
# Create a variable called "bible" which contains the text of the King James bible.
alice = nltk.corpus.gutenberg.raw('carroll-alice.txt')

# make all characters lowercase
alice = alice.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
alice = alice.replace('\n', ' ')

# split up the text into a long list of individual words
alice = alice.split(' ')

# %%
alice_rabbit = []
for i, val in enumerate(alice):
    if val.lower() == "rabbit": 
        if i >= 3 and i + 3 < len(alice):
            alice_rabbit.append(' '.join(alice[i-3:i+3]))

# %%
alice_rabbit
# Out:
# ['suddenly a white rabbit with pink',
#  'to hear the rabbit say to',
#  'but when the rabbit actually took',
#  'before seen a rabbit with either',
#  'and the white rabbit was still',
#  'corner, but the rabbit was no',
#  'was the white rabbit returning, splendidly',
#  'so, when the rabbit came near',
#  "please, sir--' the rabbit started violently,",
#  'chapter iv. the rabbit sends in',
#  'very soon the rabbit noticed alice,',
#  'it was the rabbit coming to',
#  ' presently the rabbit came up',
#  'she heard the rabbit just under',
#  "indeed!' said the rabbit angrily. 'here!",
#  "alice heard the rabbit say, 'a",
#  "hush!' said the rabbit in a",
#  'a pity!"?\' the rabbit asked. ',
#  "queen's ears--' the rabbit began. alice",
#  "'oh, hush!' the rabbit whispered in",
#  'for the white rabbit cried out,',
#  'this the white rabbit blew three',
#  "not yet!' the rabbit hastily interrupted.",
#  'and the white rabbit blew three',
#  'watched the white rabbit as he',
#  'when the white rabbit read out,',
#  "when the white rabbit interrupted: 'unimportant,",
#  ' the white rabbit put on',
#  'verses the white rabbit read:-- ',
#  'as the white rabbit hurried by--the']

# %%
len(alice_rabbit)
# Out:
# 30

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids()

for title in books:
    book = nltk.corpus.gutenberg.raw(title)

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:

books = nltk.corpus.gutenberg.fileids()

titles = []
numwords = []

for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    word_count = len(book.split())
    titles.append(title)
    numwords.append(word_count)

book_word_counts = list(zip(titles, numwords))

book_word_counts_sorted = sorted(book_word_counts, key=lambda x: x[1], reverse=True)

print(f"'{book_word_counts_sorted[0][0]}' has the most words with a total of {book_word_counts_sorted[0][1]} words.")
# Out:
# 'bible-kjv.txt' has the most words with a total of 821133 words.

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
import nltk
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
moby_dick = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')

emma = emma.lower()
emma = emma.replace('\n', ' ')
emma_words = emma.split(' ')

moby_dick = moby_dick.lower()
moby_dick = moby_dick.replace('\n', ' ')
moby_dick_words = moby_dick.split(' ')

emma_freq = nltk.FreqDist(emma_words)
moby_dick_freq = nltk.FreqDist(moby_dick_words)

emma_most_common = emma_freq.most_common(10)
moby_dick_most_common = moby_dick_freq.most_common(10)

print("Most common words in 'Emma':")
print(emma_most_common)
print("\nMost common words in 'Moby Dick':")
print(moby_dick_most_common)
# Out:
# Most common words in 'Emma':
# [('', 6290), ('the', 5120), ('to', 5079), ('and', 4445), ('of', 4196), ('a', 3055), ('i', 2602), ('was', 2302), ('she', 2169), ('in', 2091)]
#
# Most common words in 'Moby Dick':
# [('the', 12757), ('of', 6014), ('', 5720), ('and', 5629), ('to', 4192), ('a', 4095), ('in', 3756), ('\r', 3273), ('that', 2537), ('his', 2214)]

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# list of stopwords

stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
# starter code:

book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()

# code to remove stopwords
words = [word for word in words if word not in stopwords]

# %%
import nltk

nltk.download('gutenberg')
nltk.download('punkt')

emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
moby_dick = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')

emma = emma.lower()
emma = emma.replace('\n', ' ')
emma_words = emma.split(' ')

emma_words_cleaned = [word for word in emma_words if word not in stopwords]

moby_dick = moby_dick.lower()
moby_dick = moby_dick.replace('\n', ' ')
moby_dick = moby_dick.replace('\r', ' ')
moby_dick_words = moby_dick.split(' ')

moby_dick_words_cleaned = [word for word in moby_dick_words if word not in stopwords]

emma_freq_cleaned = nltk.FreqDist(emma_words_cleaned)
moby_dick_freq_cleaned = nltk.FreqDist(moby_dick_words_cleaned)

emma_most_common_cleaned = emma_freq_cleaned.most_common(10)
moby_dick_most_common_cleaned = moby_dick_freq_cleaned.most_common(10)

print("Most common words in 'Emma' (after removing stopwords):")
print(emma_most_common_cleaned)
print("\nMost common words in 'Moby Dick' (after removing stopwords):")
print(moby_dick_most_common_cleaned)
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/villiamjensen/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/villiamjensen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Most common words in 'Emma' (after removing stopwords):
# [('mr.', 1097), ('could', 800), ('would', 795), ('mrs.', 675), ('miss', 568), ('must', 543), ('emma', 481), ('much', 427), ('every', 425), ('said', 392)]
#
# Most common words in 'Moby Dick' (after removing stopwords):
# [('one', 779), ('like', 564), ('upon', 556), ('whale', 528), ('old', 425), ('would', 416), ('though', 311), ('great', 292), ('still', 282), ('seemed', 273)]
